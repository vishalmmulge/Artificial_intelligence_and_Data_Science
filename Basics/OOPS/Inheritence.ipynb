# %%
##inheritence (Single inheritance)

##parent class

class Car:
    def __init__(self,windows,doors,enginetype):
        self.windows=windows
        self.doors=doors
        self.enginetype=enginetype
    
    def drive(self):
        print(f"the person will drive the {self.enginetype} car")

# %%
car1 = Car(4,5,"CNG")
car1.drive()
# Out:
# the person will drive the CNG car

# %%
class Tesla(Car):
    def __init__(self,windows,doors,enginetype,is_selfdrive):
        super().__init__(windows,doors,enginetype)
        self.is_selfdrive = is_selfdrive
    def selfdriving(self):
        print(f"Tesla support selfdriving: {self.is_selfdrive}")

# %%
Tesla1 = Tesla(4,5,"electric",True)
Tesla1.selfdriving()
# Out:
# Tesla support selfdriving: True

# %%
### Multiple inheritance
# When a class inherits from more than one base class
class Animal:

    def __init__(self,name):
        self.name = name
    
    def speak(self):
        print("Sub class must implement this method")
    

class Pet:
    def __init__(self,owner):
        self.owner = owner

class Dog(Animal,Pet):
    def __init__(self,name,owner):
        Animal.__init__(self,name)
        Pet.__init__(self,owner)
    
    def speak(self):
        print(f"{self.name} says woof")


## creating an object
dog = Dog("tommy","Vishal")
print(dog.speak())
print(f"Owner: {dog.owner}")
# Out:
# tommy says woof
# None
# Owner: Vishal

# %%
dog1 = Dog("Buddy","babitha")
dog1.speak()
print(f"Owner: {dog1.owner}")
# Out:
# Buddy says woof
# Owner: babitha
