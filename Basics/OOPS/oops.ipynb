# %%
class Car:
    pass

audi = Car()
bmw = Car()

print(type(audi))
# Out:
# <class '__main__.Car'>

# %%
print(audi)
print(bmw)

# %%
dir(bmw)
# Out:
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__']

# %%
### Insatnce variables and methods
class Dog:
    ##constructor
    def __init__(self,name,age):
        self.name = name
        self.age = age

dog1 = Dog("Tommy",12)
print(dog1)
print(dog1.name)
print(dog1.age)
# Out:
# ...
# Tommy
# 12

# %%
dog2=Dog("Buddy", 3)

print(dog2.name, dog2.age)
# Out:
# Buddy 3

# %%
### Define a class with insatnce method
class Dog:
    
    def __init__(self,name,age):
        self.name = name
        self.age = age

    def bark(self):
        print(f"{self.name} says Woaf Woaf")

dog1 = Dog("babi" , 26)
dog1.bark()

dog2 = Dog("Tommy", 12)
dog2.bark()
# Out:
# babi says Woaf Woaf
# Tommy says Woaf Woaf

# %%
###Modling a bank account

#Define a class for bank account
class BankAccount:

    def __init__(self,owner,balance):
        self.owner = owner
        self.balance = balance
    
    def deposit(self,amount):
        self.balance += amount
        print(f"{amount} is deposited, Your new Available balance is {self.balance}")
    def withdraw(self,amount):
        if amount > self.balance:
            print("Insufficient Balance")
        else:
            self.balance -= amount
            print(f"{amount} is withdrawn, Your new Available balance is {self.balance}")

###creating a bank account
account1 = BankAccount("Vishal", 5000)
print(account1.balance)
# Out:
# 5000

# %%
account1.deposit(500)
# Out:
# 500 is deposited, Your new Available balance is 5500

# %%
account1.withdraw(1000)
# Out:
# 1000 is withdrawn, Your new Available balance is 4500

# %%
account1.withdraw(50000)
# Out:
# Insufficient Balance
