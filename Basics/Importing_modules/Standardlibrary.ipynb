# %%
import array
arr=array.array('i',[1,2,3,4])
print(arr)

# %%
import math
print(math.sqrt(16))
print(math.factorial(5))
# Out:
# 4.0
# 120

# %%
import random
print(random.randint(1, 10))
print(random.choice(['apple','bananna','cherry']))
# Out:
# 7
# apple

# %%
### File and directory access

import os 
print(os.getcwd())
# Out:
# c:\Users\visha\Desktop\LIFE\Artificial_intelligence_and_Data_Science\Basics\Importing_modules

# %%
os.mkdir('test_dir')

# %%
##high level operations on files and collections od files
import shutil
shutil.copy('source.txt', 'destination.txt')
# Out:
# 'destination.txt'

# %%
## Data Serializations

import json
data = {'name':'Vishal','age':23}
print(data)
print(type(data))


json_str = json.dumps(data)
print(json_str)
print(type(json_str))

parsed_data = json.loads(json_str)
print(parsed_data)
print(type(parsed_data))
# Out:
# <class 'dict'>
# {'name': 'Vishal', 'age': 23}
# {"name": "Vishal", "age": 23}
# <class 'str'>
# {'name': 'Vishal', 'age': 23}
# <class 'dict'>

# %%
#csv

import csv
with open('example.csv',mode='w',newline = '') as file:
    writer = csv.writer(file)
    writer.writerow(['Name','Age'])
    writer.writerow(['Alice', 30])

# %%
with open("example.csv",mode='r') as file:
    reader=csv.reader(file)
    for row in reader:
        print(row)
# Out:
# ['Name', 'Age']
# ['Alice', '30']

# %%
##datetime
from datetime import *
now = datetime.now()
print(now)
# Out:
# 2026-07-13 01:56:25.383004

# %%
yesterday = now - timedelta(days=1)
print(yesterday)
# Out:
# 2026-07-12 01:56:25.383004

# %%
## time
import time
print(time.time())
time.sleep(2)
print(time.time())
# Out:
# 1783888080.2935996
# 1783888082.294984

# %%
## Regular expression

import re
pattern = r'\d+'
text = 'I have 2 cats and 3 dogs'
match = re.search(pattern, text)
matches = re.findall(pattern, text)
print(match.group())
print(matches)
# Out:
# 2
# ['2', '3']
