# %%
import math
math.sqrt(16)
# Out:
# 4.0

# %%
from math import sqrt, pi
print(sqrt(16), pi)
print(sqrt(25))
print(pi)
# Out:
# 4.0 3.141592653589793
# 5.0
# 3.141592653589793

# %%
import numpy as np
np.array([1,2,3])
# Out:
# array([1, 2, 3])

# %%
from math import *
print(sqrt(16))
print(pi)
# Out:
# 4.0
# 3.141592653589793

# %%
from package.maths import addition
addition(6,8)
# Out:
# 14
